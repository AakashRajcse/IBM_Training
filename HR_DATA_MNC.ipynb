# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("HR_Data_MNC_Data.csv")

# %%
df.sample(5)
# Out:
#          Unnamed: 0 Employee_ID          Full_Name  Department  \
# 1964238     1964238  EMP1964239        Alicia Lamb          HR
# 968393       968393  EMP0968394       Anna Edwards       Sales
# 1195289     1195289  EMP1195290        Peter Small  Operations
# 1992447     1992447  EMP1992448  Ronald Washington       Sales
# 1688008     1688008  EMP1688009      Kenneth Davis          IT
#
#                      Job_Title   Hire_Date  \
# 1964238           HR Executive  2020-12-08
# 968393         Sales Executive  2015-01-03
# 1195289  Logistics Coordinator  2021-01-13
# 1992447        Sales Executive  2024-04-19
# 1688008      Software Engineer  2022-03-07
#
#                                                   Location  \
# 1964238                             Kellytown, Saint Lucia
# 968393                         Port Georgehaven, Australia
# 1195289  Port Patriciaside, United States Minor Outlyin...
# 1992447                                  Nancymouth, Gabon
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Employee_ID         object
#  2   Full_Name           object
#  3   Department          object
#  4   Job_Title           object
#  5   Hire_Date           object
#  6   Location            object
#  7   Performance_Rating  int64
#  8   Experience_Years    int64
#  9   Status              object
#  10  Work_Mode           object
#  11  Salary_INR          int64
# dtypes: int64(4), object(8)
# memory usage: 183.1+ MB

# %%
df.shape
# Out:
# (2000000, 12)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Employee_ID           0
# Full_Name             0
# Department            0
# Job_Title             0
# Hire_Date             0
# Location              0
# Performance_Rating    0
# Experience_Years      0
# Status                0
# Work_Mode             0
# Salary_INR            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Employee_ID', 'Full_Name', 'Department', 'Job_Title',
#        'Hire_Date', 'Location', 'Performance_Rating', 'Experience_Years',
#        'Status', 'Work_Mode', 'Salary_INR'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.sample(5)
# Out:
#         Employee_ID         Full_Name Department  \
# 1320993  EMP1320994       Leah Morris         IT
# 1132737  EMP1132738    Erica Fletcher  Marketing
# 11336    EMP0011337    Michael Porter         IT
# 788954   EMP0788955  Elizabeth Wilson         HR
# 889510   EMP0889511      Javier Mayer         IT
#
#                              Job_Title   Hire_Date  \
# 1320993                   Data Analyst  2020-09-16
# 1132737                 SEO Specialist  2015-11-17
# 11336                  DevOps Engineer  2021-02-27
# 788954   Talent Acquisition Specialist  2022-11-18
# 889510               Software Engineer  2025-07-21
#
#                                             Location  Performance_Rating  \
# 1320993              West Sarahstad, North Macedonia                   5
# 1132737                        South Robert, Namibia                   2
# 11336                    Wardchester, Norfolk Island                   3
# ...

# %%
df["Hire_Date"] = pd.to_datetime(df["Hire_Date"])
df["Hire_Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Series name: Hire_Date
# Non-Null Count    Dtype
# --------------    -----
# 2000000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 15.3 MB

# %%
df.sample(2)
# Out:
#         Employee_ID       Full_Name Department                     Job_Title  \
# 703720   EMP0703721  Brian Friedman      Sales  Business Development Manager
# 1456091  EMP1456092      James Cruz         IT             Software Engineer
#
#          Hire_Date                       Location  Performance_Rating  \
# 703720  2019-11-28         South Cynthia, Iceland                   1
# 1456091 2018-03-10  South Kevinhaven, New Zealand                   4
#
#          Experience_Years    Status Work_Mode  Salary_INR
# 703720                  5  Resigned    Remote     1367900
# 1456091                 7    Active   On-site      740106

# %%
df["Department"].unique()
# Out:
# array(['IT', 'Marketing', 'HR', 'Operations', 'Finance', 'Sales', 'R&D'],
#       dtype=object)

# %%
df["Department"].nunique()
# Out:
# 7

# %%
df["Status"].unique()
# Out:
# array(['Resigned', 'Active', 'Terminated', 'Retired'], dtype=object)

# %%
df["Location"].nunique()
# Out:
# 1593497

# %%
df["Work_Mode"].unique()
# Out:
# array(['On-site', 'Remote'], dtype=object)

# %%
df["Job_Title"].unique()
# Out:
# array(['Software Engineer', 'SEO Specialist', 'HR Manager',
#        'Logistics Coordinator', 'Finance Manager', 'Account Manager',
#        'Financial Analyst', 'Sales Executive', 'Operations Executive',
#        'HR Executive', 'Sales Director', 'DevOps Engineer',
#        'Content Strategist', 'Marketing Executive', 'Research Scientist',
#        'Accountant', 'IT Manager', 'Supply Chain Manager', 'Data Analyst',
#        'Talent Acquisition Specialist', 'Product Developer',
#        'Operations Director', 'CTO', 'Business Development Manager',
#        'Lab Technician', 'CFO', 'Brand Manager', 'HR Director',
#        'Innovation Manager'], dtype=object)

# %%
df.select_dtypes(include='object')
# Out:
#         Employee_ID         Full_Name  Department  \
# 0        EMP0000001     Joshua Nguyen          IT
# 1        EMP0000002    Julie Williams   Marketing
# 2        EMP0000003   Alyssa Martinez          HR
# 3        EMP0000004   Nicholas Valdez          IT
# 4        EMP0000005    Joel Hendricks  Operations
# ...             ...               ...         ...
# 1999995  EMP1999996      Cody Russell  Operations
# 1999996  EMP1999997      Tracey Smith          IT
# 1999997  EMP1999998         Tracy Lee       Sales
# 1999998  EMP1999999  Michael Roberson          IT
# 1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title  \
# 0                    Software Engineer
# 1                       SEO Specialist
# 2                           HR Manager
# 3                    Software Engineer
# 4                Logistics Coordinator
# ...                                ...
# 1999995          Logistics Coordinator
# ...

# %%
df.select_dtypes(include='number')
# Out:
#          Performance_Rating  Experience_Years  Salary_INR
# 0                         5                14     1585363
# 1                         2                 7      847686
# 2                         1                 2     1430084
# 3                         1                 1      990689
# 4                         5                 0      535082
# ...                     ...               ...         ...
# 1999995                   3                14      657648
# 1999996                   3                 4     1030109
# 1999997                   5                 1     1313085
# 1999998                   4                 2     1479727
# 1999999                   1                 4      993718
#
# [2000000 rows x 3 columns]

# %%
df['Status'].unique()

# %%
status = df['Status'].value_counts()

# %%
status
# Out:
# Status
# Active        1401558
# Resigned       398660
# Retired         99912
# Terminated      99870
# Name: count, dtype: int64

# %%
status.plot(kind = "pie", color = "myge", autopct = "%1.1f%%", explode=(0.03, 0.03, 0.03, 0.03))
plt.show()

# %%
status.plot(kind = "pie", autopct = "%1.1f%%", explode=(0.03, 0.03, 0.03, 0.03))
plt.show()

# %% [markdown]
# ##. 1. What is the distribution of work modes (on site, remote).

# %%
work = df["Work_Mode"].value_counts()

# %%
work
# Out:
# Work_Mode
# On-site    1199109
# Remote      800891
# Name: count, dtype: int64

# %%
work.plot(kind = "pie", colormap = "Set2", autopct= "%1.1f%%", shadow = True)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##. How many

# %%
df["Department"].value_counts()
# Out:
# Department
# IT            601042
# Sales         400031
# Operations    300095
# Marketing     240081
# Finance       199873
# HR            159119
# R&D            99759
# Name: count, dtype: int64

# %%
sns.countplot(x = "Department", data = df)
plt.show()

# %%
df["Job_Title"].value_counts()
# Out:
# Job_Title
# Software Engineer                300358
# Sales Executive                  199982
# Operations Executive             150058
# Data Analyst                     120375
# Marketing Executive              120154
# Account Manager                  119929
# Accountant                       100307
# DevOps Engineer                   90197
# Logistics Coordinator             90188
# HR Executive                      79348
# SEO Specialist                    71692
# Business Development Manager      60233
# IT Manager                        60224
# Financial Analyst                 59815
# Research Scientist                50017
# Talent Acquisition Specialist     47994
# Supply Chain Manager              44935
# Content Strategist                36154
# CTO                               29888
# Product Developer                 29872
# Finance Manager                   29799
# HR Manager                        23841
# Sales Director                    19887
# ...

# %%
plt.figure(figsize = (10, 6))
sns.countplot(x = "Job_Title", data = df)
plt.xticks(rotation=45)   
plt.tight_layout()       
plt.show()

# %%
df.groupby("Department")["Salary_INR"].mean().astype(int)
# Out:
# Department
# Finance        940411
# HR             743853
# IT            1129858
# Marketing      769936
# Operations     754626
# R&D            800377
# Sales          792957
# Name: Salary_INR, dtype: int32

# %%
df.groupby("Job_Title")["Salary_INR"].mean().astype(int).reset_index().sort_values(by = "Salary_INR", ascending = False).head(5)
# Out:
#                        Job_Title  Salary_INR
# 14                    IT Manager     2098155
# 9                Finance Manager     1743241
# 13                    HR Manager     1252401
# 3   Business Development Manager     1252016
# 26             Software Engineer     1199260

# %%
r_emp = df[df["Status"]== "Resigned"].groupby("Department")["Status"].count()

# %%
t_emp = df[df["Status"]== "Terminated"].groupby("Department")["Status"].count()

# %%
plt.figure(figsize=(8, 4))
r_emp.plot(x = r_emp.index, y = r_emp.values, kind = "bar", color = "black", legend = True, label = "Resigned")
t_emp.plot(x = t_emp.index, y = t_emp.values, kind = "bar", color = "orange", legend = True, label = "Terminated")
plt.legend(title = "Employee Status")
plt.ylabel("Count of Employee")
plt.grid()
plt.show()

# %%
df.groupby("Department")["Performance_Rating"].mean().astype(int)
# Out:
# Department
# Finance       2
# HR            2
# IT            2
# Marketing     3
# Operations    2
# R&D           3
# Sales         3
# Name: Performance_Rating, dtype: int32

# %%
df.groupby("Employee_ID")["Location"].max().astype(int)

# %%
M = df.groupby("Employee_ID")["Location"].max()

# %%
df.groupby("Employee_ID")["Location"].max()

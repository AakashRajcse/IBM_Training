# %%
import pandas as pd
data = {"aname": ["Sumit","Rahul", "Ankit"],
        "Age": [21, 23, 25],
        "salary": [2400, 3400, 540]
       }
df = pd.DataFrame(data)
print(df)
# Out:
#    aname  Age  salary
# 0  Sumit   21    2400
# 1  Rahul   23    3400
# 2  Ankit   25     540

# %%
df = pd.read_csv("C:\\Users\\hp\\OneDrive\\Desktop\\apple_products.csv")
df
# Out:
#                                 Product Name  Product URL  Brand  Sale Price  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL  Apple       49900
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL  Apple       84900
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL  Apple       84900
# 3            APPLE iPhone 8 (Silver, 256 GB)  Product URL  Apple       77000
# 4              APPLE iPhone 8 (Gold, 256 GB)  Product URL  Apple       77000
# ..                                       ...          ...    ...         ...
# 57            APPLE iPhone SE (Black, 64 GB)  Product URL  Apple       29999
# 58           APPLE iPhone 11 (Purple, 64 GB)  Product URL  Apple       46999
# 59            APPLE iPhone 11 (White, 64 GB)  Product URL  Apple       46999
# 60            APPLE iPhone 11 (Black, 64 GB)  Product URL  Apple       46999
# 61              APPLE iPhone 11 (Red, 64 GB)  Product URL  Apple       46999
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     int64
#  6   Number Of Ratings    62 non-null     int64
#  7   Number Of Reviews    62 non-null     int64
#  8   Upc                  62 non-null     object
#  9   Star Rating          62 non-null     float64
#  10  Star Rating.1        62 non-null     float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 5.5+ KB

# %%
df.describe()
# Out:
#         Age       salary
# count   3.0     3.000000
# mean   23.0  2113.333333
# std     2.0  1451.390138
# min    21.0   540.000000
# 25%    22.0  1470.000000
# 50%    23.0  2400.000000
# 75%    24.0  2900.000000
# max    25.0  3400.000000

# %%
df_new = df[['Product Name', 'Sale Price', 'Discount Percentage']]
df_new
# Out:
#                                 Product Name  Sale Price  Discount Percentage
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)       49900                    0
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)       84900                    0
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)       84900                    0
# 3            APPLE iPhone 8 (Silver, 256 GB)       77000                    0
# 4              APPLE iPhone 8 (Gold, 256 GB)       77000                    0
# ..                                       ...         ...                  ...
# 57            APPLE iPhone SE (Black, 64 GB)       29999                   24
# 58           APPLE iPhone 11 (Purple, 64 GB)       46999                   14
# 59            APPLE iPhone 11 (White, 64 GB)       46999                   14
# 60            APPLE iPhone 11 (Black, 64 GB)       46999                   14
# 61              APPLE iPhone 11 (Red, 64 GB)       46999                   14
#
# [62 rows x 3 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[3:]
# Out:
#                                          Product Name  Product URL  Brand  \
# 3                     APPLE iPhone 8 (Silver, 256 GB)  Product URL  Apple
# 4                       APPLE iPhone 8 (Gold, 256 GB)  Product URL  Apple
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)  Product URL  Apple
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)  Product URL  Apple
# 7                 APPLE iPhone 8 (Space Grey, 256 GB)  Product URL  Apple
# 8                 APPLE iPhone XS Max (Silver, 64 GB)  Product URL  Apple
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...  Product URL  Apple
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...  Product URL  Apple
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...  Product URL  Apple
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...  Product URL  Apple
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...  Product URL  Apple
# 14             APPLE iPhone 11 Pro Max (Gold, 256 GB)  Product URL  Apple
# ...

# %%
df.iloc[[2, 5,8], 0:4]
# Out:
#                            Product Name  Product URL  Brand  Sale Price
# 2  APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL  Apple       84900
# 5   APPLE iPhone 8 Plus (Silver, 64 GB)  Product URL  Apple       49900
# 8   APPLE iPhone XS Max (Silver, 64 GB)  Product URL  Apple       89900

# %%
df.loc[0:10, ['Product Name']]
# Out:
#                                          Product Name
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)
# 1            APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2                APPLE iPhone 8 Plus (Silver, 256 GB)
# 3                     APPLE iPhone 8 (Silver, 256 GB)
# 4                       APPLE iPhone 8 (Gold, 256 GB)
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 7                 APPLE iPhone 8 (Space Grey, 256 GB)
# 8                 APPLE iPhone XS Max (Silver, 64 GB)
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...

# %%
df.reset_index()
# Out:
#     index                              Product Name  Product URL  Brand  \
# 0       0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL  Apple
# 1       1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL  Apple
# 2       2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL  Apple
# 3       3           APPLE iPhone 8 (Silver, 256 GB)  Product URL  Apple
# 4       4             APPLE iPhone 8 (Gold, 256 GB)  Product URL  Apple
# ..    ...                                       ...          ...    ...
# 57     57            APPLE iPhone SE (Black, 64 GB)  Product URL  Apple
# 58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL  Apple
# 59     59            APPLE iPhone 11 (White, 64 GB)  Product URL  Apple
# 60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL  Apple
# 61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL  Apple
#
#     Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#     level_0  index                              Product Name  Product URL  \
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
df.sort_index(ascending=False,inplace=True)
df
# Out:
#     level_0  index                              Product Name  Product URL  \
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
df.sort_values(['Product Name'], ascending=[True])
# Out:
#     level_0  index                                       Product Name  \
# 56       56     56                    APPLE iPhone 11 (Black, 128 GB)
# 60       60     60                     APPLE iPhone 11 (Black, 64 GB)
# 58       58     58                    APPLE iPhone 11 (Purple, 64 GB)
# 51       51     51                      APPLE iPhone 11 (Red, 128 GB)
# 61       61     61                       APPLE iPhone 11 (Red, 64 GB)
# ..      ...    ...                                                ...
# 9         9      9  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 12       12     12  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 10       10     10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 11       11     11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 13       13     13  Apple iPhone XR (White, 128 GB) (Includes EarP...
#
#     Product URL  Brand  Sale Price    Mrp  Discount Percentage  \
# ...

# %%
df.reset_index(drop=True)
# Out:
#     level_0  index                              Product Name  Product URL  \
# 0        61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 1        60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 2        59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 3        58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 4        57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 57        4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 58        3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 59        2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 60        1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 61        0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
fc = df['Product Name'] == 'south'
df.loc[fc]
df
# Out:
#     level_0  index                              Product Name  Product URL  \
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
 df.loc[df['Product Name'] == 'south']
df
# Out:
#     level_0  index                              Product Name  Product URL  \
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
df.loc[(df['Product Name'] == 'south') & (df['Sale Price']>0)]
# Out:
# Empty DataFrame
# Columns: [level_0, index, Product Name, Product URL, Brand, Sale Price, Mrp, Discount Percentage, Number Of Ratings, Number Of Reviews, Upc, Star Rating, Star Rating.1]
# Index: []

# %%
df.loc[(df['Product Name'] == 'south') | (df['Sale Price']>0)]
# Out:
#     level_0  index                              Product Name  Product URL  \
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
df.loc[~(df['Product Name'] == 'south')]
# Out:
#     level_0  index                              Product Name  Product URL  \
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
df.drop(columns='Product Name')
# Out:
#     level_0  index  Product URL  Brand  Sale Price    Mrp  \
# 61       61     61  Product URL  Apple       46999  54900
# 60       60     60  Product URL  Apple       46999  54900
# 59       59     59  Product URL  Apple       46999  54900
# 58       58     58  Product URL  Apple       46999  54900
# 57       57     57  Product URL  Apple       29999  39900
# ..      ...    ...          ...    ...         ...    ...
# 4         4      4  Product URL  Apple       77000  77000
# 3         3      3  Product URL  Apple       77000  77000
# 2         2      2  Product URL  Apple       84900  84900
# 1         1      1  Product URL  Apple       84900  84900
# 0         0      0  Product URL  Apple       49900  49900
#
#     Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 61                   14              43470               3331
# 60                   14              43470               3331
# 59                   14              43470               3331
# ...

# %%
df['Number Of Ratings_flag'] = 1
df
# Out:
#     level_0  index                              Product Name  Product URL  \
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...

# %%
df['Product Name'].apply(len)
# Out:
# 61    28
# 60    30
# 59    30
# 58    31
# 57    30
#       ..
# 4     29
# 3     31
# 2     36
# 1     40
# 0     33
# Name: Product Name, Length: 62, dtype: int64

# %%
df['Product Name_len'] = df['Product Name'].apply(len)
df
# Out:
#     level_0  index                              Product Name  Product URL  \
# 61       61     61              APPLE iPhone 11 (Red, 64 GB)  Product URL
# 60       60     60            APPLE iPhone 11 (Black, 64 GB)  Product URL
# 59       59     59            APPLE iPhone 11 (White, 64 GB)  Product URL
# 58       58     58           APPLE iPhone 11 (Purple, 64 GB)  Product URL
# 57       57     57            APPLE iPhone SE (Black, 64 GB)  Product URL
# ..      ...    ...                                       ...          ...
# 4         4      4             APPLE iPhone 8 (Gold, 256 GB)  Product URL
# 3         3      3           APPLE iPhone 8 (Silver, 256 GB)  Product URL
# 2         2      2      APPLE iPhone 8 Plus (Silver, 256 GB)  Product URL
# 1         1      1  APPLE iPhone 8 Plus (Space Grey, 256 GB)  Product URL
# 0         0      0         APPLE iPhone 8 Plus (Gold, 64 GB)  Product URL
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# ...
